# %% [markdown]
# # SAP Estudio
#
# Notebook inicial para explorar extracciones de clientes y facturas desde SAP.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
PROJECT_ROOT

# %% [markdown]
# ## Proxima actividad
#
# Definir campos reales de clientes y facturas, luego probar la extraccion o cargar archivos exportados desde SAP.
